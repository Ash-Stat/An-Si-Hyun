# %% [markdown]
# <a href="https://colab.research.google.com/github/Ash-Stat/An-Si-Hyun/blob/data/%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
try :
  os.mkdir('python')
  print('폴더 생성 완료')
except FileExistsError as e:
  print(e)
# Out:
# [Errno 17] File exists: 'python'

# %%
import bs4
from bs4 import BeautifulSoup
from urllib.request import urlopen

response=urlopen('https://en.wikipedia.org/wiki/Main_Page')
soup = BeautifulSoup(response,'html.parser')
for anchor in soup.find_all('a'):
  print(anchor.get('href','/'))
#위키피디아 크롤링
# Out:
# /
# #mw-head
# #searchInput
# /wiki/Wikipedia
# /wiki/Free_content
# /wiki/Encyclopedia
# /wiki/Help:Introduction_to_Wikipedia
# /wiki/Special:Statistics
# /wiki/English_language
# /wiki/Portal:Arts
# /wiki/Portal:Biography
# /wiki/Portal:Geography
# /wiki/Portal:History
# /wiki/Portal:Mathematics
# /wiki/Portal:Science
# /wiki/Portal:Society
# /wiki/Portal:Technology
# /wiki/Wikipedia:Contents/Portals
# /wiki/File:John_Charles,_Wales_versus_Scotland,_Ninian_Park,_1954.jpg
# /wiki/John_Charles
# /wiki/History_of_the_Wales_national_football_team_(1876%E2%80%931976)
# /wiki/Wales_national_football_team
# /wiki/Association_football
# /wiki/Scotland_national_football_team
# /wiki/England_national_football_team
# /wiki/Ireland_national_football_team_(1882%E2%80%931950)
# /wiki/British_Home_Championship
# /wiki/1906%E2%80%9307_British_Home_Championship
# /wiki/World_War_II
# /wiki/FIFA_World_Cup
# /wiki/1950_FIFA_World_Cup
# /wiki/1954_FIFA_World_Cup
# /wiki/1958_FIFA_World_Cup
# ...

# %%
import bs4
from bs4 import BeautifulSoup
from urllib.request import urlopen

response=urlopen('https://www.naver.com/')
soup = BeautifulSoup(response,'html.parser')
for ee in soup.select('span.keyword'):
  print(ee)

  #soup.select('title <- 이자리에 찾고자하는 태그 (span)같은게 온다.')
  #soup.select('body a') <-- body라는 태그안에서 a라는걸 선택해라

# %%
pip install google_images_download
# Out:
# ...
#      |████████████████████████████████| 911kB 3.9MB/s
# ...
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=14550 sha256=ce6007ca415116b73def7b99ed154949c17aaa1b1e27d6eeb5464a0e6235d411
#   Stored in directory: /root/.cache/pip/wheels/1f/28/ad/f56e7061e1d2a9a1affe2f9c649c2570cb9198dd24ede0bbab
# Successfully built google-images-download
# ...

# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
from urllib.parse import quote_plus
 
baseUrl = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
plusUrl = input('검색어 입력: ') 
crawl_num = int(input('크롤링할 갯수 입력(최대 50개): '))
 
url = baseUrl + quote_plus(plusUrl) # 한글 검색 자동 변환
html = urlopen(url)
soup = bs(html, "html.parser")
img = soup.find_all(class_='_img')
 
n = 1
for i in img:
    print(n)
    imgUrl = i['data-source']
    with urlopen(imgUrl) as f:
        with open('./images/img' + str(n)+'.jpg','wb') as h: # w - write b - binary
            img = f.read()
            h.write(img)
    n += 1
    if n > crawl_num:
        break
    
    
print('Image Crawling is done.')
# Out:
# 검색어 입력: 강아지
# 크롤링할 갯수 입력(최대 50개): 3
# 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-1a1bf184afd3> in <module>()
#      17     imgUrl = i['data-source']
#      18     with urlopen(imgUrl) as f:
# ---> 19         with open('./images/img' + str(n)+'.jpg','wb') as h: # w - write b - binary
#      20             img = f.read()
#      21             h.write(img)
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/img1.jpg'

# %%
import bs4
import lxml#구문을 분석하는 passer

import requests
from bs4 import BeautifulSoup

url='https://comic.naver.com/index.nhn'
res=requests.get(url)
res.raise_for_status() #문제가 있을시 종료

soup=BeautifulSoup(res.text,'lxml') #soup이 lxml이라는 파서를 통로로 모든 정보를 갖고있음
#print(soup.title)
#print(soup.title.get_text())
#print(soup.a) #a태그가 메인메뉴 바로가기임 홈페이지에서

#print(soup.a.attrs) #정보확인(a 속성 정보)

#print(soup.a['href']) #(a속성 값 정보)
#print(soup.find('a',atts={'class':'Nbtn_upload'}))  #a태그에서 Nbtn_upload라는 속성을 갖는 정보가 무엇인지 찾는것

#print(soup.find(atts={'class':'Nbtn_upload'})) #이것도 가능은 하다 class가 엔버튼인 요소를 찾아줘
#print(soup.find('li', attrs={'class' : 'rank01'}))
rank1 = soup.find('li',attrs={'class':'rank01'})
#print(rank1.a.get_text()) #텍스트만 가져와준다.

#print(rank1.next_sibling) #다음 요소로 넘어간다. #만약 이렇게해서 안되면 next_sibling을 두번 써준다.
#print(rank1.next_sibling.next_sibling)  #이렇게 해서 되면 중간에 개행 정보가 있는 걸 수도 있다.

rank2=rank1.next_sibling.next_sibling
rank3=rank2.next_sibling.next_sibling
#print(rank3.get_text())

#print(rank1.parent) #바로 부모로 건너뛰어서 다나온다.

rank1.find_next_sibling('li') #li라는 태그를 기준으로 다음 요소를 찾아준다.
#print(rank1)
#next_sibling 과 previous_sibling도 가능하다.

r1=rank1.find_next_siblings('li') #다가져온다.
#print(r1)

webtoon=soup.find('a',text='독립일기-11화 밥공기 딜레마')
print(webtoon)
# Out:
# None

# %%
import requests
from bs4 import BeautifulSoup
import lxml
url = 'https://comic.naver.com/webtoon/weekday.nhn'
res=requests.get(url)
res.raise_for_status()

soup=BeautifulSoup(res.text,'lxml')

#네이버 웹툰 전체 목록 가져오기

cartoons = soup.find_all('a',attrs={'class' : 'title'})
for cartoon in cartoons:
  print(cartoon.get_text())
# Out:
# 인생존망
# 뷰티풀 군바리
# 윈드브레이커
# 소녀의 세계
# 백수세끼
# 장씨세가 호위무사
# 파이게임
# 바이러스X
# 앵무살수
# 유일무이 로맨스
# 칼가는 소녀
# 오늘의 순정망화
# 왕따협상
# 링크보이
# 싸이코 리벤지
# 히어로메이커
# 평범한 8반
# 아는 여자애
# 노력의 결과
# 사장님을 잠금해제
# 삶이 우리를 속일지라도
# 리턴 투 플레이어
# 결혼생활 그림일기
# 이중첩자
# 이것도 친구라고
# 침범
# 일진이 사나워
# 꿈의 기업
# 서브 콤플렉스
# 와이키키 뱀파이어
# 피플
# 정보전사 202
# 안녕 나의 모모로
# 도플갱어의 게임
# 두근두근 네가 좋아서
# 헬로맨스
# 원하는 건 너 하나
# 하슬라
# 지구멸망버튼
# 여기 악마가 있어
# 인간의 온도
# 뱀파이어의 꽃
# 드로잉 레시피
# 백호랑
# 모락모락 왕세자님
# 물레
# 블루투스
# 결백한 사람은 없다
# 중독연구소
# 여신강림
# 관계의 종말
# 한림체육관
# 후기
# 바른연애 길잡이
# 랜덤채팅의 그녀!
# 하루만 네가 되고 싶어
# 사신소년
# 헬58
# 신도림
# 성인초딩
# 중증외상센터 : 골든 아워
# 삼국지톡
# 빅맨
# 원주민 공포만화
# 달콤살벌한 부부
# 오늘의 순정망화
# 2020 호랑 공포 단편선
# 아이레
# 집이 없어
# 오피스 누나 이야기
# 체크포인트
# 윌유메리미
# 견우와 선녀
# 악마와 계약연애
# 연우의 순정
# 용왕님의 셰프가 되었습니다
# 사이드킥 2~3
# 플레이, 플리
# 신의 언어
# 땅 보고 걷는 아이
# 정년이
# 제로게임
# 완벽한 가족
# 은주의 방 2~3부
# 그놈은 흑염룡
# 올가미
# 한강예찬
# 오파츠
# 숲속의 담
# 자판귀
# 별종
# 도를 아십니까
# 언메이크
# 너에게만 보이는
# 조선홍보대행사 조대박
# 그날 죽은 나는
# 필살VS로맨스
# 저세상 클라스!
# 안식의 밤
# 아이고 아이고
# 장단에 맞춰줘!
# 빛빛빛
# 호랑이 들어와요
# 헬퍼 2 : 킬베로스
# 고수
# 전지적 독자 시점
# ...

# %%
import lxml
import bs4
from bs4 import BeautifulSoup
import requests
url='https://comic.naver.com/webtoon/weekday.nhn'
res=requests.get(url)
res.raise_for_status()

soup=BeautifulSoup(res.text,'lxml')

cartoons=soup.find_all('a',attrs={'class' : 'title'})
for cartoon in cartoons:
  print(cartoon.get_text())
# Out:
# 인생존망
# 뷰티풀 군바리
# 윈드브레이커
# 소녀의 세계
# 백수세끼
# 장씨세가 호위무사
# 파이게임
# 바이러스X
# 앵무살수
# 유일무이 로맨스
# 칼가는 소녀
# 오늘의 순정망화
# 왕따협상
# 링크보이
# 싸이코 리벤지
# 히어로메이커
# 평범한 8반
# 아는 여자애
# 노력의 결과
# 사장님을 잠금해제
# 삶이 우리를 속일지라도
# 리턴 투 플레이어
# 결혼생활 그림일기
# 이중첩자
# 이것도 친구라고
# 침범
# 일진이 사나워
# 꿈의 기업
# 서브 콤플렉스
# 와이키키 뱀파이어
# 피플
# 정보전사 202
# 안녕 나의 모모로
# 도플갱어의 게임
# 두근두근 네가 좋아서
# 헬로맨스
# 원하는 건 너 하나
# 하슬라
# 지구멸망버튼
# 여기 악마가 있어
# 인간의 온도
# 뱀파이어의 꽃
# 드로잉 레시피
# 백호랑
# 모락모락 왕세자님
# 물레
# 블루투스
# 결백한 사람은 없다
# 중독연구소
# 여신강림
# 관계의 종말
# 한림체육관
# 후기
# 바른연애 길잡이
# 랜덤채팅의 그녀!
# 하루만 네가 되고 싶어
# 사신소년
# 헬58
# 신도림
# 성인초딩
# 중증외상센터 : 골든 아워
# 삼국지톡
# 빅맨
# 원주민 공포만화
# 달콤살벌한 부부
# 오늘의 순정망화
# 2020 호랑 공포 단편선
# 아이레
# 집이 없어
# 오피스 누나 이야기
# 체크포인트
# 윌유메리미
# 견우와 선녀
# 악마와 계약연애
# 연우의 순정
# 용왕님의 셰프가 되었습니다
# 사이드킥 2~3
# 플레이, 플리
# 신의 언어
# 땅 보고 걷는 아이
# 정년이
# 제로게임
# 완벽한 가족
# 은주의 방 2~3부
# 그놈은 흑염룡
# 올가미
# 한강예찬
# 오파츠
# 숲속의 담
# 자판귀
# 별종
# 도를 아십니까
# 언메이크
# 너에게만 보이는
# 조선홍보대행사 조대박
# 그날 죽은 나는
# 필살VS로맨스
# 저세상 클라스!
# 안식의 밤
# 아이고 아이고
# 장단에 맞춰줘!
# 빛빛빛
# 호랑이 들어와요
# 헬퍼 2 : 킬베로스
# 고수
# 전지적 독자 시점
# ...

# %%
from urllib.request import Request, urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
baseUrl='https://www.google.com/search?q='  # 검색엔진의 구문을 해석한다. 예를들어서 구글 창에서 저 사과를 검색하면
                                            #https://www.google.com/search?q=사과 가 되어 검색결과가 뜨고 포도를 검색하면
                                            #https://www.google.com/search?q=포도 가 되어 검색결과가 뜬다. 즉 이때의 베이스 주소는
                                            #https://www.google.com/search?q= 가 되는 것이다.
plusUrl=input('검색어를 입력하세요.')
plusUrl2='&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj3v73x89PsAhUIGKYKHQRoBWsQ_AUoAXoECAYQAw&biw=1920&bih=937'
#&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj3v73x89PsAhUIGKYKHQRoBWsQ_AUoAXoECAYQAw&biw=1920&bih=937 이미지 탭을 누르면 주소가 이렇게 바뀌는게 이게 이미지 탭으로 가게 해주는 주소
#url=baseUrl+plusUrl+plusUrl2 #https://www.google.com/search?q=검색어 형태로 만들어 주기 위함, 따라서 url은 #&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj3v73x89PsAhUIGKYKHQRoBWsQ_AUoAXoECAYQAw&biw=1920&bih=937 이것도 고려


#하지만 아스키 코드를 이용해야만 쓸 수 있다. 그래서

urls=baseUrl+quote_plus(plusUrl)+plusUrl2 #이렇게 아스키코드로 입력값을 변환해주는 코드를 입력해야만 한다.
print(urls)
req=Request('https://www.google.com/search?q=%EC%97%B0%EC%84%B8&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj3v73x89PsAhUIGKYKHQRoBWsQ_AUoAXoECAYQAw&biw=1920&bih=937')
html2 = urlopen(req).read()
soup=BeautifulSoup(html2,'html2.parser') #html을 이용해서 BeautifulSoup 을 이용하여 분석한다.
#img = soup.find_all('img',attrs={'class' : 'rg_i Q4LuWd'})
#print(img)
#구글은 막힌다.
# Out:
# 검색어를 입력하세요.연세
# https://www.google.com/search?q=%EC%97%B0%EC%84%B8&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj3v73x89PsAhUIGKYKHQRoBWsQ_AUoAXoECAYQAw&biw=1920&bih=937
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-53-d74efefbd5b1> in <module>()
#      17 print(urls)
#      18 req=Request('https://www.google.com/search?q=%EC%97%B0%EC%84%B8&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj3v73x89PsAhUIGKYKHQRoBWsQ_AUoAXoECAYQAw&biw=1920&bih=937')
# ---> 19 html2 = urlopen(req).read()
#      20 soup=BeautifulSoup(html2,'html2.parser') #html을 이용해서 BeautifulSoup 을 이용하여 분석한다.
#      21 #img = soup.find_all('img',attrs={'class' : 'rg_i Q4LuWd'})
#
# /usr/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
# ...

# %%
from urllib.request import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
baseUrl='https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
plusUrl=input('검색어를 입력하세요.')
url=baseUrl+quote_plus(plusUrl)
print(url)
html=urlopen(url).read()
soup=BeautifulSoup(html,'html.parser')
img=soup.find_all(class_='_img')
#print(img)

#하나만 가져오는 방법
print(img[0])

#<img alt="예쁜 딸기 사진 | 블로그" class="_img" data-height="768" 
#data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2Fdata2%2F2004%2F2%2F5%2F69%2F%25B5%25FE%25B1%25E2%25BB%25E7%25C1%25F83.jpg&amp;type=b400" 
#data-width="1024" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');"
#src="..."/>

#이것처럼 실제 홈페이지 개발자 도구에서 따온 소스랑 파이썬으로 추출한 주소랑 다를 수 있다.

for i in img:
  print(i['data-source']) #그래서 데이터 소스만 따온다.
  print()
# Out:
# 검색어를 입력하세요.딸기
# https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EB%94%B8%EA%B8%B0
# <img alt="예쁜 딸기 사진 | 블로그" class="_img" data-height="768" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2Fdata2%2F2004%2F2%2F5%2F69%2F%25B5%25FE%25B1%25E2%25BB%25E7%25C1%25F83.jpg&amp;type=b400" data-width="1024" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2Fdata2%2F2004%2F2%2F5%2F69%2F%25B5%25FE%25B1%25E2%25BB%25E7%25C1%25F83.jpg&type=b400
#
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2F20120315_158%2Fdiet44go_1331772010270gE4ks_JPEG%2F%25B5%25FE%25B1%25E2.jpg&type=b400
#
# https://search.pstatic.net/common/?src=http%3A%2F%2Fimgnews.naver.net%2Fimage%2F014%2F2014%2F01%2F16%2F2014011601001787500086761_59_20140116162502.jpg&type=b400
#
# ...

# %%
n = 1
for i in img:
  imgUrl = i['data-source']
  with urlopen(imgUrl) as berry:
    with open(plusUrl + str(n) + '.jpg','wb') as good :# 어떤 이름으로 저장할까, 확장자, w-> 쓴다, b->텍스트 가아니라 이미지기 때문에 바이너리이다. 그래서 b를 넣어준다.
      img= berry.read()
      good.write(img)
  n += 1
  print('다운로드 완료')
  print(imgUrl)
# Out:
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료
# 다운로드 완료

# %%
###이미지 크롤링###
from urllib.request import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
baseUrl='https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
plusUrl=input('검색어를 입력하세요.')
url=baseUrl+quote_plus(plusUrl)
print(url)
html=urlopen(url).read()
soup=BeautifulSoup(html,'html.parser')
img=soup.find_all(class_='_img')
#print(img)

#하나만 가져오는 방법
print(img[0])

#<img alt="예쁜 딸기 사진 | 블로그" class="_img" data-height="768" 
#data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2Fdata2%2F2004%2F2%2F5%2F69%2F%25B5%25FE%25B1%25E2%25BB%25E7%25C1%25F83.jpg&amp;type=b400" 
#data-width="1024" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');"
#src="..."/>

#이것처럼 실제 홈페이지 개발자 도구에서 따온 소스랑 파이썬으로 추출한 주소랑 다를 수 있다.

for i in img:
  print(i['data-source']) #그래서 데이터 소스만 따온다.
  print()

n = 1
for i in img:
  imgUrl = i['data-source']
  with urlopen(imgUrl) as berry:
    with open(plusUrl + str(n) + '.jpg','wb') as good :# 어떤 이름으로 저장할까, 확장자, w-> 쓴다, b->텍스트 가아니라 이미지기 때문에 바이너리이다. 그래서 b를 넣어준다.
      img= berry.read()
      good.write(img)
  n += 1
  print('다운로드 완료')
  print(imgUrl)
# Out:
# 검색어를 입력하세요.고양이
# https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EA%B3%A0%EC%96%91%EC%9D%B4
# <img alt="안녕하세요! 선팔/맞팔/하트친구/하트100/품앗이 대환영입니다! | 포스트" class="_img" data-height="550" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fpost.phinf.naver.net%2FMjAxNzA1MDRfMTQx%2FMDAxNDkzODg4ODcxNjgz.z4btPaGstH2fWnZblzKcy6GLtInIxpA7aX5XiflRgFMg.vZFPH2D1ewspOkjwpkA6w8M0Nvj7jJTUmJtsqGPJd3gg.PNG%2FIEJdx4U8WBQ4EDweMldQelV8mFm0.jpg&amp;type=b400" data-width="550" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>
# https://search.pstatic.net/common/?src=http%3A%2F%2Fpost.phinf.naver.net%2FMjAxNzA1MDRfMTQx%2FMDAxNDkzODg4ODcxNjgz.z4btPaGstH2fWnZblzKcy6GLtInIxpA7aX5XiflRgFMg.vZFPH2D1ewspOkjwpkA6w8M0Nvj7jJTUmJtsqGPJd3gg.PNG%2FIEJdx4U8WBQ4EDweMldQelV8mFm0.jpg&type=b400
#
# ...
