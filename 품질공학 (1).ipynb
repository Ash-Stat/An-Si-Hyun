# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def BassModel(t,M,p,q):
  t=t-2020
  a=q/p
  b=p+q
  return M*(1-np.exp(-b*t))/(1+a*np.exp(-b*t))

x=np.arange(2020,2065,0.1)
print(BassModel(x,1650041000,0.002496,0.132501))
# Out:
# [0.00000000e+00 4.14538542e+05 8.34498674e+05 1.25994843e+06
#  1.69095663e+06 2.12759287e+06 2.56992754e+06 3.01803182e+06
#  3.47197770e+06 3.93183798e+06 4.39768628e+06 4.86959704e+06
#  5.34764553e+06 5.83190786e+06 6.32246099e+06 6.81938273e+06
#  7.32275173e+06 7.83264752e+06 8.34915050e+06 8.87234195e+06
#  9.40230402e+06 9.93911977e+06 1.04828731e+07 1.10336490e+07
#  1.15915330e+07 1.21566120e+07 1.27289735e+07 1.33087060e+07
#  1.38958990e+07 1.44906428e+07 1.50930289e+07 1.57031495e+07
#  1.63210979e+07 1.69469683e+07 1.75808559e+07 1.82228568e+07
#  1.88730682e+07 1.95315882e+07 2.01985159e+07 2.08739515e+07
#  2.15579961e+07 2.22507517e+07 2.29523215e+07 2.36628096e+07
#  2.43823212e+07 2.51109625e+07 2.58488407e+07 2.65960641e+07
#  2.73527418e+07 2.81189842e+07 2.88949027e+07 2.96806097e+07
#  3.04762185e+07 3.12818438e+07 3.20976010e+07 3.29236068e+07
#  3.37599788e+07 3.46068357e+07 3.54642973e+07 3.63324845e+07
# ...

# %%
plt.title("BassModelRegression M=1,650.041×10^6, q=0.132501")

plt.plot(x, BassModel(x,1650041000,0.002493,0.132501), 'y--', label='p=0.002493')
plt.plot(x, BassModel(x,1650041000,0.0005,0.132501), 'm--', label='p=0.0005')
plt.plot(x, BassModel(x,1650041000,0.0010,0.132501), 'c--', label='p=0.0010')
plt.plot(x, BassModel(x,1650041000,0.0025,0.132501), 'b:', label='p=0.0025')
plt.plot(x, BassModel(x,1650041000,0.0037,0.132501), 'r', label='p=0.0037')
plt.plot(x, BassModel(x,1650041000,0.0050,0.132501), 'b--', label='p=0.0050')
plt.plot(x, BassModel(x,1650041000,0.0075,0.132501), 'g--', label='p=0.0075')
plt.plot(x, BassModel(x,1650041000,0.0100,0.132501), 'k--', label='p=0.0100')


plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("iPhone Sales Volume")
plt.show()

# %%
plt.figure()
plt.title("BassModelRegression M=1,650.041×10^6, p=0.002493")
plt.plot(x, BassModel(x,1650041000,0.002493,0.134107), 'y--', label='0.134107')
plt.plot(x, BassModel(x,1650041000,0.002493,0.0010), 'y--', label='q=0.0010')
plt.plot(x, BassModel(x,1650041000,0.002493,0.0100), 'm--', label='q=0.0100')
plt.plot(x, BassModel(x,1650041000,0.002493,0.1000), 'c--', label='q=0.1000')
plt.plot(x, BassModel(x,1650041000,0.002493,0.1500), 'b:', label='q=0.1000')
plt.plot(x, BassModel(x,1650041000,0.002493,0.2500), 'r', label='q=0.25')
plt.plot(x, BassModel(x,1650041000,0.002493,0.3454), 'b--', label='q=0.3454')
plt.plot(x, BassModel(x,1650041000,0.002493,0.5000), 'g--', label='q=0.5000')
plt.plot(x, BassModel(x,1650041000,0.002493,0.7500), 'k--', label='q=0.7500')

plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("iPhone Sales Volume")
plt.show()

# %%
plt.title("BassModelRegression M=2,458.518×10^6, q=0.134107")

plt.plot(x, BassModel(x,2458518000,0.007898,0.134107), 'y--', label='p=0.007898')
plt.plot(x, BassModel(x,2458518000,0.0005,0.134107), 'm--', label='p=0.0005')
plt.plot(x, BassModel(x,2458518000,0.0010,0.134107), 'c--', label='p=0.0010')
plt.plot(x, BassModel(x,2458518000,0.0025,0.134107), 'b:', label='p=0.0025')
plt.plot(x, BassModel(x,2458518000,0.0037,0.134107), 'r', label='p=0.0037')
plt.plot(x, BassModel(x,2458518000,0.0050,0.134107), 'b--', label='p=0.0050')
plt.plot(x, BassModel(x,2458518000,0.0075,0.134107), 'g--', label='p=0.0075')
plt.plot(x, BassModel(x,2458518000,0.0100,0.134107), 'k--', label='p=0.0100')


plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("Samsung Sales Volume")
plt.show()

# %%
plt.figure()
plt.title("BassModelRegression M=2,458.518×10^6, p=0.007898")
plt.plot(x, BassModel(x,2458518000,0.007898,0.134107), 'y--', label='0.134107')
plt.plot(x, BassModel(x,2458518000,0.007898,0.0010), 'y--', label='q=0.0010')
plt.plot(x, BassModel(x,2458518000,0.007898,0.0100), 'm--', label='q=0.0100')
plt.plot(x, BassModel(x,2458518000,0.007898,0.1000), 'c--', label='q=0.1000')
plt.plot(x, BassModel(x,2458518000,0.007898,0.1500), 'b:', label='q=0.1000')
plt.plot(x, BassModel(x,2458518000,0.007898,0.2500), 'r', label='q=0.25')
plt.plot(x, BassModel(x,2458518000,0.007898,0.3454), 'b--', label='q=0.3454')
plt.plot(x, BassModel(x,2458518000,0.007898,0.5000), 'g--', label='q=0.5000')
plt.plot(x, BassModel(x,2458518000,0.007898,0.7500), 'k--', label='q=0.7500')

plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("Samsung Sales Volume")
plt.show()

# %%
def BassModel(t, M, p, q):
  t=t-2020
  q>0
  p>0
  a=q/p
  b=p+q
  return M*(1-np.exp(-b*t))/(1+a*np.exp(-b*t))

# %%
plt.title("BassModelRegression M=1,650.041×10^6, q=0.132501")

plt.plot(x, BassModel(x,1650041000,0.002493,0.132501), 'y--', label='p=0.002493')
plt.plot(x, BassModel(x,1650041000,0.0005,0.132501), 'm--', label='p=0.0005')
plt.plot(x, BassModel(x,1650041000,0.0010,0.132501), 'c--', label='p=0.0010')
plt.plot(x, BassModel(x,1650041000,0.0025,0.132501), 'b:', label='p=0.0025')
plt.plot(x, BassModel(x,1650041000,0.0037,0.132501), 'r', label='p=0.0037')
plt.plot(x, BassModel(x,1650041000,0.0050,0.132501), 'b--', label='p=0.0050')
plt.plot(x, BassModel(x,1650041000,0.0075,0.132501), 'g--', label='p=0.0075')
plt.plot(x, BassModel(x,1650041000,0.0100,0.132501), 'k--', label='p=0.0100')


plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("iPhone Sales Volume")
plt.show()

# %%
plt.figure()
plt.title("BassModelRegression M=1,650.041×10^6, p=0.002493")
plt.plot(x, BassModel(x,1650041000,0.002493,0.134107), 'y--', label='0.134107')
plt.plot(x, BassModel(x,1650041000,0.002493,0.0010), 'y--', label='q=0.0010')
plt.plot(x, BassModel(x,1650041000,0.002493,0.0100), 'm--', label='q=0.0100')
plt.plot(x, BassModel(x,1650041000,0.002493,0.1000), 'c--', label='q=0.1000')
plt.plot(x, BassModel(x,1650041000,0.002493,0.1500), 'b:', label='q=0.1000')
plt.plot(x, BassModel(x,1650041000,0.002493,0.2500), 'r', label='q=0.25')
plt.plot(x, BassModel(x,1650041000,0.002493,0.3454), 'b--', label='q=0.3454')
plt.plot(x, BassModel(x,1650041000,0.002493,0.5000), 'g--', label='q=0.5000')
plt.plot(x, BassModel(x,1650041000,0.002493,0.7500), 'k--', label='q=0.7500')

plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("iPhone Sales Volume")
plt.show()

# %%
plt.title("BassModelRegression M=2,458.518×10^6, q=0.134107")

plt.plot(x, BassModel(x,2458518000,0.007898,0.134107), 'y--', label='p=0.007898')
plt.plot(x, BassModel(x,2458518000,0.0005,0.134107), 'm--', label='p=0.0005')
plt.plot(x, BassModel(x,2458518000,0.0010,0.134107), 'c--', label='p=0.0010')
plt.plot(x, BassModel(x,2458518000,0.0025,0.134107), 'b:', label='p=0.0025')
plt.plot(x, BassModel(x,2458518000,0.0037,0.134107), 'r', label='p=0.0037')
plt.plot(x, BassModel(x,2458518000,0.0050,0.134107), 'b--', label='p=0.0050')
plt.plot(x, BassModel(x,2458518000,0.0075,0.134107), 'g--', label='p=0.0075')
plt.plot(x, BassModel(x,2458518000,0.0100,0.134107), 'k--', label='p=0.0100')


plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("Samsung Sales Volume")
plt.show()

# %%
plt.figure()
plt.title("BassModelRegression M=2,458.518×10^6, p=0.007898")
plt.plot(x, BassModel(x,2458518000,0.007898,0.134107), 'y--', label='0.134107')
plt.plot(x, BassModel(x,2458518000,0.007898,0.0010), 'y--', label='q=0.0010')
plt.plot(x, BassModel(x,2458518000,0.007898,0.0100), 'm--', label='q=0.0100')
plt.plot(x, BassModel(x,2458518000,0.007898,0.1000), 'c--', label='q=0.1000')
plt.plot(x, BassModel(x,2458518000,0.007898,0.1500), 'b:', label='q=0.1000')
plt.plot(x, BassModel(x,2458518000,0.007898,0.2500), 'r', label='q=0.25')
plt.plot(x, BassModel(x,2458518000,0.007898,0.3454), 'b--', label='q=0.3454')
plt.plot(x, BassModel(x,2458518000,0.007898,0.5000), 'g--', label='q=0.5000')
plt.plot(x, BassModel(x,2458518000,0.007898,0.7500), 'k--', label='q=0.7500')

plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("Samsung Sales Volume")
plt.show()

# %%
def BassModel(t,M,p,q):
  t=t-2020
  a=q/p
  b=p+q
  #M*(1-np.exp(-b*t))/(1+a*np.exp(-b*t))
  return M*((b**2)/p)*np.exp(-b*t)/(1+a*np.exp(-b*t))**2
x=np.arange(2020,2065,0.1)

# %%
plt.title("BassModelRegression M=1,650.041×10^6, q=0.132501")

plt.plot(x, BassModel(x,1650041000,0.002493,0.132501), 'yx', label='p=0.002493')
plt.plot(x, BassModel(x,1650041000,0.0005,0.132501), 'mx', label='p=0.0005')
plt.plot(x, BassModel(x,1650041000,0.0010,0.132501), 'cx', label='p=0.0010')
plt.plot(x, BassModel(x,1650041000,0.0025,0.132501), 'b--', label='p=0.0025')
plt.plot(x, BassModel(x,1650041000,0.0037,0.132501), 'rx', label='p=0.0037')
plt.plot(x, BassModel(x,1650041000,0.0050,0.132501), 'bx', label='p=0.0050')
plt.plot(x, BassModel(x,1650041000,0.0075,0.132501), 'gx', label='p=0.0075')
plt.plot(x, BassModel(x,1650041000,0.0100,0.132501), 'kx', label='p=0.0100')


plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("iPhone Sales Volume")
plt.show()

# %%
plt.figure()
plt.title("BassModelRegression M=1,650.041×10^6, p=0.002493")
plt.plot(x, BassModel(x,1650041000,0.002493,0.134107), 'yx', label='0.134107')
plt.plot(x, BassModel(x,1650041000,0.002493,0.0010), 'mx', label='q=0.0010')
plt.plot(x, BassModel(x,1650041000,0.002493,0.0100), 'cx', label='q=0.0100')
plt.plot(x, BassModel(x,1650041000,0.002493,0.1000), 'b--', label='q=0.1000')
plt.plot(x, BassModel(x,1650041000,0.002493,0.1500), 'rx', label='q=0.1000')
plt.plot(x, BassModel(x,1650041000,0.002493,0.2500), 'bx', label='q=0.25')
plt.plot(x, BassModel(x,1650041000,0.002493,0.3454), 'gx', label='q=0.3454')
plt.plot(x, BassModel(x,1650041000,0.002493,0.5000), 'kx', label='q=0.5000')
plt.plot(x, BassModel(x,1650041000,0.002493,0.7500), 'k--', label='q=0.7500')

plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("iPhone Sales Volume")
plt.show()

# %%
plt.title("BassModelRegression M=2,458.518×10^6, q=0.134107")

plt.plot(x, BassModel(x,2458518000,0.007898,0.134107), 'yx', label='p=0.007898')
plt.plot(x, BassModel(x,2458518000,0.0005,0.134107), 'mx', label='p=0.0005')
plt.plot(x, BassModel(x,2458518000,0.0010,0.134107), 'cx', label='p=0.0010')
plt.plot(x, BassModel(x,2458518000,0.0025,0.134107), 'b--', label='p=0.0025')
plt.plot(x, BassModel(x,2458518000,0.0037,0.134107), 'rx', label='p=0.0037')
plt.plot(x, BassModel(x,2458518000,0.0050,0.134107), 'bx', label='p=0.0050')
plt.plot(x, BassModel(x,2458518000,0.0075,0.134107), 'gx', label='p=0.0075')
plt.plot(x, BassModel(x,2458518000,0.0100,0.134107), 'kx', label='p=0.0100')


plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("Samsung Sales Volume")
plt.show()

# %%
plt.figure()
plt.title("BassModelRegression M=2,458.518×10^6, p=0.007898")
plt.plot(x, BassModel(x,2458518000,0.007898,0.134107), 'yx', label='0.134107')
plt.plot(x, BassModel(x,2458518000,0.007898,0.0010), 'mx', label='q=0.0010')
plt.plot(x, BassModel(x,2458518000,0.007898,0.0100), 'cx', label='q=0.0100')
plt.plot(x, BassModel(x,2458518000,0.007898,0.1000), 'b--', label='q=0.1000')
plt.plot(x, BassModel(x,2458518000,0.007898,0.1500), 'rx', label='q=0.1000')
plt.plot(x, BassModel(x,2458518000,0.007898,0.2500), 'bx', label='q=0.25')
plt.plot(x, BassModel(x,2458518000,0.007898,0.3454), 'gx', label='q=0.3454')
plt.plot(x, BassModel(x,2458518000,0.007898,0.5000), 'kx', label='q=0.5000')
plt.plot(x, BassModel(x,2458518000,0.007898,0.7500), 'k--', label='q=0.7500')

plt.legend(loc='lower right')
plt.xticks([2020,2025,2030,2035,2040,2045,2050,2055,2060,2065])
plt.xlabel("Year")
plt.ylabel("Samsung Sales Volume")
plt.show()

# %%
def BassModel(M,p,q):
  #t=t-2020
  a=q/p
  b=p+q
  #M*(1-np.exp(-b*t))/(1+a*np.exp(-b*t))
  #return M*((b**2)/p)*np.exp(-b*t)/(1+a*np.exp(-b*t))**2
  return np.log10(a)/b
x=np.arange(2020,2065,0.1)
print(BassModel(2458518000,0.007898,0.134107))
# Out:
# 8.66120430947213

# %%
def HazardModel(p,q):
  a=q/p
  b=p+q
  return (np.log10(a))/b
print('아이폰,q가 0.132501 고정일때')
print('')
print('t*' +':' +str(HazardModel(0.002493,0.132501)))
print('t*' +':' +str(HazardModel(0.0005,0.132501)))
print('t*' +':' +str(HazardModel(0.0010,0.132501)))
print('t*' +':' +str(HazardModel(0.0025,0.132501)))
print('t*' +':' +str(HazardModel(0.0037,0.132501)))
print('t*' +':' +str(HazardModel(0.0050,0.132501)))
print('t*' +':' +str(HazardModel(0.0075,0.132501)))
print('t*' +':' +str(HazardModel(0.0100,0.132501)))
print('-----------------------------------------')
print('아이폰,p가 0.002493 고정일때')
print('')
print('t*' +':' +str(HazardModel(0.002493,0.134107)))
print('t*' +':' +str(HazardModel(0.002493,0.0010)))
print('t*' +':' +str(HazardModel(0.002493,0.0100)))
print('t*' +':' +str(HazardModel(0.002493,0.1000)))
print('t*' +':' +str(HazardModel(0.002493,0.1500)))
print('t*' +':' +str(HazardModel(0.002493,0.2500)))
print('t*' +':' +str(HazardModel(0.002493,0.3454)))
print('t*' +':' +str(HazardModel(0.002493,0.5000)))
print('t*' +':' +str(HazardModel(0.002493,0.7500)))
print('-----------------------------------------')
print('삼성,q가 0.134107 고정일때')
print('')
print('t*' +':' +str(HazardModel(0.007898,0.134107)))
print('t*' +':' +str(HazardModel(0.0005,0.134107)))
print('t*' +':' +str(HazardModel(0.0010,0.134107)))
print('t*' +':' +str(HazardModel(0.0025,0.134107)))
print('t*' +':' +str(HazardModel(0.0037,0.134107)))
print('t*' +':' +str(HazardModel(0.0050,0.134107)))
print('t*' +':' +str(HazardModel(0.0075,0.134107)))
print('t*' +':' +str(HazardModel(0.0100,0.134107)))
print('-----------------------------------------')
print('삼성,p가 0.007898 고정일때')
print('')
print('t*' +':' +str(HazardModel(0.007898,0.134107)))
print('t*' +':' +str(HazardModel(0.007898,0.0010)))
print('t*' +':' +str(HazardModel(0.007898,0.0100)))
print('t*' +':' +str(HazardModel(0.007898,0.1000)))
print('t*' +':' +str(HazardModel(0.007898,0.1500)))
print('t*' +':' +str(HazardModel(0.007898,0.2500)))
print('t*' +':' +str(HazardModel(0.007898,0.3454)))
print('t*' +':' +str(HazardModel(0.007898,0.5000)))
print('t*' +':' +str(HazardModel(0.007898,0.7500)))
# Out:
# 아이폰,q가 0.132501 고정일때
#
# t*:12.782026441552125
# t*:18.21978144238496
# t*:15.896653627723095
# t*:12.772343518067448
# t*:11.409735845461237
# t*:10.350827642116364
# t*:8.908207031113784
# t*:7.875166882721251
# -----------------------------------------
# 아이폰,p가 0.002493 고정일때
#
# t*:12.670052480697962
# t*:-113.57637518000956
# t*:48.289259705133
# t*:15.642802157183677
# t*:11.668528919700629
# t*:7.925834499048544
# t*:6.155915913018274
# t*:4.581651338092761
# t*:3.2935043713203003
# -----------------------------------------
# 삼성,q가 0.134107 고정일때
#
# t*:8.66120430947213
# t*:18.04127157600345
# t*:15.746419114976389
# t*:12.660489130828415
# t*:11.314735269617072
# t*:10.268940046375064
# t*:8.844126236523724
# t*:7.823710488505867
# -----------------------------------------
# 삼성,p가 0.007898 고정일때
#
# t*:8.66120430947213
# t*:-100.86728808726964
# t*:5.725939803300627
# t*:10.21782489572999
# t*:8.09746880679398
# t*:5.817892652411078
# t*:4.644252738002804
# ...
